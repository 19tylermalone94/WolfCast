# %%
# --- Colab setup: run this cell once ---
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import rasterio

# Adjust this if needed
COMPOSITE_DIR = Path("/content/drive/MyDrive/WolfCast_Satellite_Data")

def count_pixels_in_tif(tif_path: Path):
    """Return (width, height, pixel_count) for the TIFF."""
    with rasterio.open(tif_path) as src:
        width = src.width
        height = src.height
        pixels = width * height
        return width, height, pixels

def main():
    tif_files = sorted(COMPOSITE_DIR.glob("*.tif"))

    if not tif_files:
        print("No TIFF files found in:", COMPOSITE_DIR)
        return

    print(f"Found {len(tif_files)} TIFF files.\n")

    grand_total = 0

    for tif in tif_files:
        width, height, pixels = count_pixels_in_tif(tif)
        grand_total += pixels

        print(f"{tif.name}:")
        print(f"   width       = {width}")
        print(f"   height      = {height}")
        print(f"   pixel count = {pixels:,}")
        print()

    print("======================================")
    print(f"TOTAL pixels across all TIF files: {grand_total:,}")
    print("======================================")

if __name__ == "__main__":
    main()
# Out:
# Found 29 TIFF files.
#
# wolfcast_1995.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_1996.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_1997.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_1998.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_1999.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2000.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2001.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2002.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2003.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2004.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2005.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2006.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2007.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2008.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2009.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2010.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2011.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2012.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2013.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2014.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2015.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2016.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2017.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2018.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2019.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2020.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2021.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_2022.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# wolfcast_nlcd_2019.tif:
#    width       = 7010
#    height      = 8407
#    pixel count = 58,933,070
#
# ======================================
# TOTAL pixels across all TIF files: 1,709,059,030
# ======================================

# %%
# !gsutil -m cp -r "/content/drive/MyDrive/WolfCast_Satellite_Data/*.tif" gs://wolfcast_training_samples/data/
# Out:
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_nlcd_2019.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2020.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2021.tif [Content-Type=image/tiff]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2022.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2019.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2017.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2013.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2015.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2016.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2018.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2014.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2011.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2012.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2010.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2008.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2007.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2006.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2004.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2005.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2002.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2003.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2009.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2000.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_1999.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_1998.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_2001.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_1997.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_1995.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data/wolfcast_1996.tif [Content-Type=image/tiff]...
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ResumableUploadAbortException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# ServiceException: 401 Anonymous caller does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).
# CommandException: 29 files/objects could not be transferred.

# %%
# !gsutil -m cp -r "/content/drive/MyDrive/WolfCast_Satellite_Data_labels/*.tif" gs://wolfcast_training_samples/labels/
# Out:
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2003.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_1999.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_1998.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_1996.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_1997.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2004.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2000.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2002.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2001.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_1995.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2005.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2006.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2007.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2008.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2009.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2010.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2011.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2012.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2013.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2014.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2015.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2016.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2017.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2018.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2019.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2021.tif [Content-Type=image/tiff]...
# Copying file:///content/drive/MyDrive/WolfCast_Satellite_Data_labels/wolf_presence_2022.tif [Content-Type=image/tiff]...
# -
# Operation completed over 27 objects/11.2 MiB.

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# !gsutil -m cp -r "/content/drive/MyDrive/wolf_training_samples_2x/*.parquet" gs://wolfcast_training_samples/training_samples_halfpos/
# Out:
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2000.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2001.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_1995.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_1999.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_1998.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2004.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2002.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2003.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_1997.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_1996.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2005.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2006.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2007.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2008.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2009.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2010.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2011.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2012.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2013.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2014.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2015.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2016.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2017.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2018.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2019.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2021.parquet [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/wolf_training_samples_2x/samples_2022.parquet [Content-Type=application/octet-stream]...
# - [27/27 files][  2.5 GiB/  2.5 GiB] 100% Done  85.7 MiB/s ETA 00:00:00
# Operation completed over 27 objects/2.5 GiB.
